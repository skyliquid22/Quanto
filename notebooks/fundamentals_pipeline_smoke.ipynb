# %% [markdown]
# # Pipeline End-to-End Smoke Notebook
#
# This notebook runs the ingestion -> canonicalization -> experiment -> evaluation -> monitoring flow step by step.
# Edit only the parameters in the next cell, then run top to bottom.

# %%
# Parameters (edit only here)
EQUITY_INGEST_CONFIG = "configs/ingest/equity_smoke.yml"
FIN_DATASETS_CONFIG = "configs/ingest/financialdatasets_smoke.yml"
DATA_SOURCES_CONFIG = "configs/data_sources.yml"

EQUITY_DOMAIN = "equity_ohlcv"
FINANCIALDATASETS_DOMAINS = [
    "financial_statements",
    "company_facts",
    "financial_metrics",
    "financial_metrics_snapshot",
    "insider_trades",
    "institutional_ownership",
    "news",
]

EQUITY_RUN_ID = "equity_smoke"
FIN_DATASETS_RUN_TAG = "financialdatasets_smoke"

CANON_START_DATE = "2020-01-01"
CANON_END_DATE = "2024-12-31"

EXPERIMENT_SPEC = "configs/experiments/core_v1_regime_ppo.yml"
EXPERIMENT_FORCE = False
EXPERIMENT_ID = ""  # leave blank to auto-detect latest after run

BASELINE_EXPERIMENT_ID = ""  # optional, for qualification

RUN_QUALIFY = False
RUN_SHADOW = False
FORCE_INGEST = False
STRICT = False

# %%
# Setup
import os
import json
import subprocess
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

PYTHON = sys.executable


def run_cmd(cmd, *, check=True):
    print("\n$", " ".join(cmd))
    result = subprocess.run(cmd, cwd=PROJECT_ROOT, capture_output=True, text=True)
    if result.stdout:
        print(result.stdout)
    if result.stderr:
        print(result.stderr)
    if check and result.returncode != 0:
        raise RuntimeError(f"Command failed with code {result.returncode}")
    return result


def latest_experiment_id(data_root=None):
    root = Path(data_root or PROJECT_ROOT / ".quanto_data") / "experiments"
    if not root.exists():
        return None
    candidates = [p for p in root.iterdir() if p.is_dir()]
    if not candidates:
        return None
    return max(candidates, key=lambda p: p.stat().st_mtime).name

# %% [markdown]
# ## Step 0: Preflight
# Check API keys and config paths before running heavy steps.

# %%
print("FINANCIALDATASETS_API_KEY set:", bool(os.environ.get("FINANCIALDATASETS_API_KEY")))
print("POLYGON_API_KEY set:", bool(os.environ.get("POLYGON_API_KEY")))
print("Equity config exists:", Path(PROJECT_ROOT / EQUITY_INGEST_CONFIG).exists())
print("Financial Datasets config exists:", Path(PROJECT_ROOT / FIN_DATASETS_CONFIG).exists())
# Out:
# FINANCIALDATASETS_API_KEY set: True
# POLYGON_API_KEY set: True
# Equity config exists: True
# Financial Datasets config exists: True

# %% [markdown]
# ## Step 1: Ingest equity OHLCV (raw)

# %%
cmd = [
    PYTHON,
    "-m",
    "scripts.ingest",
    "--domain",
    EQUITY_DOMAIN,
    "--config",
    EQUITY_INGEST_CONFIG,
    "--mode",
    "rest",
]
if EQUITY_RUN_ID:
    cmd += ["--run-id", EQUITY_RUN_ID]
if FORCE_INGEST:
    cmd.append("--force")
run_cmd(cmd, check=not STRICT)
# Out:
# $ /opt/anaconda3/envs/quanto/bin/python3.12 -m scripts.ingest --domain equity_ohlcv --config configs/ingest/equity_smoke.yml --mode rest --run-id equity_smoke
# {
#   "adapter": "PolygonEquityAdapter",
#   "config_path": "configs/ingest/equity_smoke.yml",
#   "domain": "equity_ohlcv",
#   "error": "Manifest /Users/ahmed/PycharmProjects/Quanto/.quanto_data/raw/polygon/equity_ohlcv/manifests/equity_smoke.json already exists. Re-run with --force to overwrite.",
#   "mode": "rest",
#   "run_id": "equity_smoke",
#   "status": "failed",
#   "vendor": "polygon"
# }
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 16
#      14 if FORCE_INGEST:
#      15     cmd.append("--force")
# ---> 16 run_cmd(cmd, check=not STRICT)
#
# Cell In[2], line 26, in run_cmd(cmd, check)
#      24     print(result.stderr)
#      25 if check and result.returncode != 0:
# ---> 26     raise RuntimeError(f"Command failed with code {result.returncode}")
#      27 return result
#
# RuntimeError: Command failed with code 1

# %% [markdown]
# ## Step 2: Ingest Financial Datasets raw domains
# Each domain uses the same config but a domain-specific run-id.

# %%
for domain in FINANCIALDATASETS_DOMAINS:
    cmd = [
        PYTHON,
        "-m",
        "scripts.ingest",
        "--domain",
        domain,
        "--config",
        FIN_DATASETS_CONFIG,
        "--mode",
        "rest",
        "--run-id",
        f"{domain}-{FIN_DATASETS_RUN_TAG}",
    ]
    if FORCE_INGEST:
        cmd.append("--force")
    run_cmd(cmd, check=not STRICT)
# Out:
# $ /opt/anaconda3/envs/quanto/bin/python3.12 -m scripts.ingest --domain financial_statements --config configs/ingest/financialdatasets_smoke.yml --mode rest --run-id financial_statements-financialdatasets_smoke
# {
#   "adapter": "FinancialDatasetsAdapter",
#   "config_path": "configs/ingest/financialdatasets_smoke.yml",
#   "domain": "financial_statements",
#   "files_written": [
#     {
#       "hash": "sha256:fdfd9c2265ea226b47f3fa5349d49376dcfe4dd03fecec9bcde92f5a63e9988d",
#       "path": "/Users/ahmed/PycharmProjects/Quanto/.quanto_data/raw/financialdatasets/financial_statements/AAPL/2022/09/24.parquet",
#       "records": 1
#     },
#     {
#       "hash": "sha256:b56382fd77b6752f6072fbcef3cc6a43d46120d5b05a610bc780555ed8985c2f",
#       "path": "/Users/ahmed/PycharmProjects/Quanto/.quanto_data/raw/financialdatasets/financial_statements/AAPL/2023/09/30.parquet",
#       "records": 1
#     },
#     {
#       "hash": "sha256:f39ce9bfdb17549238a784eba3553bc0f4b2d46fa8311604db90073396211b6b",
#       "path": "/Users/ahmed/PycharmProjects/Quanto/.quanto_data/raw/financialdatasets/financial_statements/AAPL/2024/09/28.parquet",
#       "records": 1
#     },
#     {
#       "hash": "sha256:25fe0f3ced8ef1dbc4c9dcc2fb324049692b35890447f74e5ccc690b2ad9d182",
#       "path": "/Users/ahmed/PycharmProjects/Quanto/.quanto_data/raw/financialdatasets/financial_statements/AAPL/2025/09/27.parquet",
#       "records": 1
#     },
#     {
#       "hash": "sha256:4e067a2ac7ecd46dcfa105898a0d674371ed5320f2741910f6632c18c654a694",
#       "path": "/Users/ahmed/PycharmProjects/Quanto/.quanto_data/raw/financialdatasets/financial_statements/MSFT/2022/06/30.parquet",
#       "records": 1
#     },
#     {
#       "hash": "sha256:165a698b00b84e2496732ccc50b5fa7152ab3222c48ec476bf93904b4b61f77f",
#       "path": "/Users/ahmed/PycharmProjects/Quanto/.quanto_data/raw/financialdatasets/financial_statements/MSFT/2023/06/30.parquet",
#       "records": 1
#     },
#     {
#       "hash": "sha256:e773991e7be4bf94a292ee08751b664c27009a4e9202307038879c06c84dc271",
#       "path": "/Users/ahmed/PycharmProjects/Quanto/.quanto_data/raw/financialdatasets/financial_statements/MSFT/2024/06/30.parquet",
#       "records": 1
#     },
#     {
#       "hash": "sha256:801bfda340bb71fa356a4d6d8d8232714e035b5431d16e4a9661dbc687bd0029",
#       "path": "/Users/ahmed/PycharmProjects/Quanto/.quanto_data/raw/financialdatasets/financial_statements/MSFT/2025/06/30.parquet",
#       "records": 1
#     }
#   ],
#   "manifest_path": "/Users/ahmed/PycharmProjects/Quanto/.quanto_data/raw/financialdatasets/financial_statements/manifests/financial_statements-financialdatasets_smoke.json",
#   "mode": "rest",
#   "run_id": "financial_statements-financialdatasets_smoke",
#   "status": "succeeded",
#   "validation_manifests": [
#     {
#       "creation_timestamp": "2020-10-22T23:58:15+00:00",
#       "domain": "fundamentals",
#       "input_file_hashes": [],
#       "invalid_records": 0,
#       "manifest_path": "/Users/ahmed/PycharmProjects/Quanto/.quanto_data/raw/financialdatasets/financial_statements/manifests/validation/fundamentals/financial_statements-financialdatasets_smoke.json",
#       "run_id": "financial_statements-financialdatasets_smoke",
#       "schema_version": "1.2",
#       "source_vendor": "financialdatasets",
#       "total_records": 8,
#       "valid_records": 8,
#       "validation_status": "passed"
#     }
#   ],
#   "vendor": "financialdatasets"
# }
#
#
# $ /opt/anaconda3/envs/quanto/bin/python3.12 -m scripts.ingest --domain company_facts --config configs/ingest/financialdatasets_smoke.yml --mode rest --run-id company_facts-financialdatasets_smoke
# {
#   "adapter": "FinancialDatasetsAdapter",
#   "config_path": "configs/ingest/financialdatasets_smoke.yml",
#   "domain": "company_facts",
#   "files_written": [
#     {
#       "hash": "sha256:659e6cc99b2436fdae9fb1211b5ddbc930f45f9db6702f07e150428905cb81ef",
#       "path": "/Users/ahmed/PycharmProjects/Quanto/.quanto_data/raw/financialdatasets/company_facts/AAPL/2023/12/31.parquet",
#       "records": 1
#     },
#     {
#       "hash": "sha256:ce8871a0617a55529f7d186e7dd6d1c37f8a510494727e8c5be03456a4e08710",
#       "path": "/Users/ahmed/PycharmProjects/Quanto/.quanto_data/raw/financialdatasets/company_facts/MSFT/2023/12/31.parquet",
#       "records": 1
#     }
#   ],
#   "manifest_path": "/Users/ahmed/PycharmProjects/Quanto/.quanto_data/raw/financialdatasets/company_facts/manifests/company_facts-financialdatasets_smoke.json",
#   "mode": "rest",
#   "run_id": "company_facts-financialdatasets_smoke",
#   "status": "succeeded",
#   "validation_manifests": [],
#   "vendor": "financialdatasets"
# }
#
#
# $ /opt/anaconda3/envs/quanto/bin/python3.12 -m scripts.ingest --domain financial_metrics --config configs/ingest/financialdatasets_smoke.yml --mode rest --run-id financial_metrics-financialdatasets_smoke
# {
#   "adapter": "FinancialDatasetsAdapter",
#   "config_path": "configs/ingest/financialdatasets_smoke.yml",
#   "domain": "financial_metrics",
#   "files_written": [
#     {
#       "hash": "sha256:50e2774e30d5303b807f0fbe68d9af699256f9079e03639ad94659fb88ca8262",
#       "path": "/Users/ahmed/PycharmProjects/Quanto/.quanto_data/raw/financialdatasets/financial_metrics/AAPL/2023/12/31.parquet",
#       "records": 1
#     },
#     {
#       "hash": "sha256:02a616bdb1376e260694c848ee99b0751356c4c3a80b2efd4d2244b1999bed6c",
#       "path": "/Users/ahmed/PycharmProjects/Quanto/.quanto_data/raw/financialdatasets/financial_metrics/MSFT/2023/12/31.parquet",
#       "records": 1
#     }
#   ],
#   "manifest_path": "/Users/ahmed/PycharmProjects/Quanto/.quanto_data/raw/financialdatasets/financial_metrics/manifests/financial_metrics-financialdatasets_smoke.json",
#   "mode": "rest",
#   "run_id": "financial_metrics-financialdatasets_smoke",
#   "status": "succeeded",
#   "validation_manifests": [],
#   "vendor": "financialdatasets"
# }
#
#
# $ /opt/anaconda3/envs/quanto/bin/python3.12 -m scripts.ingest --domain financial_metrics_snapshot --config configs/ingest/financialdatasets_smoke.yml --mode rest --run-id financial_metrics_snapshot-financialdatasets_smoke
# {
#   "adapter": "FinancialDatasetsAdapter",
#   "config_path": "configs/ingest/financialdatasets_smoke.yml",
#   "domain": "financial_metrics_snapshot",
#   "files_written": [
#     {
#       "hash": "sha256:1eb523fc724e466ef7a40965efc602a8fe132db709ad9f6c1602166411902fd0",
#       "path": "/Users/ahmed/PycharmProjects/Quanto/.quanto_data/raw/financialdatasets/financial_metrics_snapshot/AAPL/2023/12/31.parquet",
#       "records": 1
#     },
#     {
#       "hash": "sha256:0a419a8b019060c3782e67308a4bf570b22bc5a79b412774dae655d67c0a3db9",
#       "path": "/Users/ahmed/PycharmProjects/Quanto/.quanto_data/raw/financialdatasets/financial_metrics_snapshot/MSFT/2023/12/31.parquet",
#       "records": 1
#     }
#   ],
#   "manifest_path": "/Users/ahmed/PycharmProjects/Quanto/.quanto_data/raw/financialdatasets/financial_metrics_snapshot/manifests/financial_metrics_snapshot-financialdatasets_smoke.json",
#   "mode": "rest",
#   "run_id": "financial_metrics_snapshot-financialdatasets_smoke",
#   "status": "succeeded",
#   "validation_manifests": [],
#   "vendor": "financialdatasets"
# }
#
#
# $ /opt/anaconda3/envs/quanto/bin/python3.12 -m scripts.ingest --domain insider_trades --config configs/ingest/financialdatasets_smoke.yml --mode rest --run-id insider_trades-financialdatasets_smoke
# {
#   "adapter": "FinancialDatasetsAdapter",
#   "config_path": "configs/ingest/financialdatasets_smoke.yml",
#   "domain": "insider_trades",
#   "files_written": [
#     {
#       "hash": "sha256:8b3aec61ab4a2e1327556f736c2c7c3e65bd1e4c94adfbefed094bd1f198dc96",
#       "path": "/Users/ahmed/PycharmProjects/Quanto/.quanto_data/raw/financialdatasets/insider_trades/AAPL/2025/10/16.parquet",
#       "records": 3
#     },
#     {
#       "hash": "sha256:2d41f7378ef5b7b70a89207b5296f27a299ba3d8e3c05e5aded7d1877e9f9f37",
#       "path": "/Users/ahmed/PycharmProjects/Quanto/.quanto_data/raw/financialdatasets/insider_trades/AAPL/2025/11/07.parquet",
#       "records": 1
#     },
#     {
#       "hash": "sha256:4fe2aa67f7de5b65a003fd72a771505e53451c9126098924647380d7fea09317",
#       "path": "/Users/ahmed/PycharmProjects/Quanto/.quanto_data/raw/financialdatasets/insider_trades/MSFT/2025/05/05.parquet",
#       "records": 1
#     },
#     {
#       "hash": "sha256:251b5116d4d165d4661c48b27611852200c12970d15b4d5591e704372fa87fad",
#       "path": "/Users/ahmed/PycharmProjects/Quanto/.quanto_data/raw/financialdatasets/insider_trades/MSFT/2025/12/15.parquet",
#       "records": 2
#     },
#     {
#       "hash": "sha256:283d4b3862919ee1c270332d6f37f7164d5b2fe7803181605ee0e9c58536738d",
#       "path": "/Users/ahmed/PycharmProjects/Quanto/.quanto_data/raw/financialdatasets/insider_trades/MSFT/2026/01/15.parquet",
#       "records": 1
#     }
#   ],
#   "manifest_path": "/Users/ahmed/PycharmProjects/Quanto/.quanto_data/raw/financialdatasets/insider_trades/manifests/insider_trades-financialdatasets_smoke.json",
#   "mode": "rest",
#   "run_id": "insider_trades-financialdatasets_smoke",
#   "status": "succeeded",
#   "validation_manifests": [],
#   "vendor": "financialdatasets"
# }
#
#
# $ /opt/anaconda3/envs/quanto/bin/python3.12 -m scripts.ingest --domain institutional_ownership --config configs/ingest/financialdatasets_smoke.yml --mode rest --run-id institutional_ownership-financialdatasets_smoke
# {
#   "adapter": "FinancialDatasetsAdapter",
#   "config_path": "configs/ingest/financialdatasets_smoke.yml",
#   "domain": "institutional_ownership",
#   "files_written": [],
#   "manifest_path": "/Users/ahmed/PycharmProjects/Quanto/.quanto_data/raw/financialdatasets/institutional_ownership/manifests/institutional_ownership-financialdatasets_smoke.json",
#   "mode": "rest",
#   "run_id": "institutional_ownership-financialdatasets_smoke",
#   "status": "succeeded",
#   "validation_manifests": [],
#   "vendor": "financialdatasets"
# }
#
#
# $ /opt/anaconda3/envs/quanto/bin/python3.12 -m scripts.ingest --domain news --config configs/ingest/financialdatasets_smoke.yml --mode rest --run-id news-financialdatasets_smoke
# {
#   "adapter": null,
#   "config_path": "configs/ingest/financialdatasets_smoke.yml",
#   "domain": "news",
#   "error": "Invalid isoformat string: '2023-12-31T18:30:00Z'",
#   "mode": null,
#   "run_id": "news-financialdatasets_smoke",
#   "status": "failed",
#   "vendor": "financialdatasets"
# }
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 17
#      15 if FORCE_INGEST:
#      16     cmd.append("--force")
# ---> 17 run_cmd(cmd, check=not STRICT)
#
# Cell In[2], line 26, in run_cmd(cmd, check)
#      24     print(result.stderr)
#      25 if check and result.returncode != 0:
# ---> 26     raise RuntimeError(f"Command failed with code {result.returncode}")
#      27 return result
#
# RuntimeError: Command failed with code 1

# %% [markdown]
# ## Step 3: Build canonical datasets
# This will produce canonical equity + fundamentals from raw inputs.

# %%
cmd = [
    PYTHON,
    "-m",
    "scripts.build_canonical_datasets",
    "--config",
    DATA_SOURCES_CONFIG,
    "--domains",
    "equity_ohlcv",
    "fundamentals",
    "--start-date",
    CANON_START_DATE,
    "--end-date",
    CANON_END_DATE,
]
run_cmd(cmd, check=not STRICT)

# %% [markdown]
# ## Step 4: Run experiment

# %%
cmd = [
    PYTHON,
    "-m",
    "scripts.run_experiment",
    "--spec",
    EXPERIMENT_SPEC,
]
if EXPERIMENT_FORCE:
    cmd.append("--force")
run_cmd(cmd, check=not STRICT)

if not EXPERIMENT_ID:
    EXPERIMENT_ID = latest_experiment_id()
print("Experiment ID:", EXPERIMENT_ID)

# %% [markdown]
# ## Step 5: Evaluation and regime slices

# %%
if EXPERIMENT_ID:
    run_cmd([PYTHON, "-m", "scripts.run_regime_slices", "--experiment-id", EXPERIMENT_ID], check=not STRICT)

# %% [markdown]
# ## Step 6: Qualification (optional)

# %%
if RUN_QUALIFY and EXPERIMENT_ID and BASELINE_EXPERIMENT_ID:
    cmd = [
        PYTHON,
        "-m",
        "scripts.qualify_experiment",
        "--experiment-id",
        EXPERIMENT_ID,
        "--baseline",
        BASELINE_EXPERIMENT_ID,
    ]
    run_cmd(cmd, check=not STRICT)

# %% [markdown]
# ## Step 7: Monitoring report (ASCII tables + plots)

# %%
from research.monitoring.experiment_report import generate_experiment_report, format_table

if EXPERIMENT_ID:
    report = generate_experiment_report(EXPERIMENT_ID, strict=False, inline=True)
    print(format_table(report["metrics_table"]))
    if not report["comparison_table"].empty:
        print(format_table(report["comparison_table"]))
    if not report["winner_table"].empty:
        print(format_table(report["winner_table"]))

# %% [markdown]
# ## Step 8: Quick artifact check

# %%
if EXPERIMENT_ID:
    exp_dir = PROJECT_ROOT / ".quanto_data" / "experiments" / EXPERIMENT_ID
    print("Experiment dir:", exp_dir)
    for rel in ["evaluation/metrics.json", "evaluation/timeseries.json", "evaluation/regime_slices.json", "promotion/qualification_report.json"]:
        path = exp_dir / rel
        print(f"{rel}:", path.exists())
