# %%
import asyncio
from datetime import date

from infra.ingestion.adapters import EquityIngestionRequest, PolygonEquityAdapter
from infra.ingestion.adapters import PolygonRESTClient  # real client
from infra.ingestion.data_pipeline import EquityIngestionPipeline

rest_client = PolygonRESTClient(api_key="YOUR_POLYGON_KEY")
adapter = PolygonEquityAdapter(rest_client=rest_client)
pipeline = EquityIngestionPipeline(adapter=adapter)

request = EquityIngestionRequest(
  vendor="polygon",
  symbols=("AAPL", "MSFT"),
  start_date=date(2024, 1, 1),
  end_date=date(2024, 1, 5),
  flat_file_uris=(),
  options={},
)

loop = asyncio.get_running_loop()
manifest = await loop.run_in_executor(
  None,
  lambda: pipeline.run(request, run_id="demo_equity_ingest"),
)
manifest
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 8
#       5 from infra.ingestion.adapters import PolygonRESTClient  # real client
#       6 from infra.ingestion.data_pipeline import EquityIngestionPipeline
# ----> 8 rest_client = PolygonRESTClient()
#       9 adapter = PolygonEquityAdapter(rest_client=rest_client)
#      10 pipeline = EquityIngestionPipeline(adapter=adapter)
#
# TypeError: PolygonRESTClient.__init__() missing 1 required positional argument: 'api_key'

# %%
  import pandas as pd
  pd.read_parquet(
      ".quanto_data/canonical/equity_ohlcv/AAPL/daily/2023.parquet",
      engine="pyarrow",
  )
# Out:
#       close                creation_timestamp fallback_source_vendor  \
# 0    125.07  2026-01-09T21:09:36.572190+00:00                   None
# 1    126.36  2026-01-09T21:09:36.572190+00:00                   None
# 2    125.02  2026-01-09T21:09:36.572190+00:00                   None
# 3    129.62  2026-01-09T21:09:36.572190+00:00                   None
# 4    130.15  2026-01-09T21:09:36.572190+00:00                   None
# ..      ...                               ...                    ...
# 245  193.60  2026-01-09T21:09:36.572190+00:00                   None
# 246  193.05  2026-01-09T21:09:36.572190+00:00                   None
# 247  193.15  2026-01-09T21:09:36.572190+00:00                   None
# 248  193.58  2026-01-09T21:09:36.572190+00:00                   None
# 249  192.53  2026-01-09T21:09:36.572190+00:00                   None
#
#          high                                  input_file_hashes      low  \
# 0    130.9000  [sha256:eaccb36111a36118d8f6c0c2512e9350689836...  124.170
# 1    128.6557  [sha256:eaccb36111a36118d8f6c0c2512e9350689836...  125.080
# 2    127.7700  [sha256:eaccb36111a36118d8f6c0c2512e9350689836...  124.760
# 3    130.2900  [sha256:eaccb36111a36118d8f6c0c2512e9350689836...  124.890
# 4    133.4100  [sha256:eaccb36111a36118d8f6c0c2512e9350689836...  129.890
# ..        ...                                                ...      ...
# 245  195.4100  [sha256:eaccb36111a36118d8f6c0c2512e9350689836...  192.970
# 246  193.8900  [sha256:eaccb36111a36118d8f6c0c2512e9350689836...  192.830
# 247  193.5000  [sha256:eaccb36111a36118d8f6c0c2512e9350689836...  191.090
# 248  194.6600  [sha256:eaccb36111a36118d8f6c0c2512e9350689836...  193.170
# 249  194.4000  [sha256:eaccb36111a36118d8f6c0c2512e9350689836...  191.725
#
#         open partition_day primary_source_vendor reconcile_method  \
# 0    130.280    2023-01-03               polygon          primary
# 1    126.890    2023-01-04               polygon          primary
# 2    127.130    2023-01-05               polygon          primary
# 3    126.010    2023-01-06               polygon          primary
# 4    130.465    2023-01-09               polygon          primary
# ..       ...           ...                   ...              ...
# 245  195.180    2023-12-22               polygon          primary
# 246  193.610    2023-12-26               polygon          primary
# 247  192.490    2023-12-27               polygon          primary
# 248  194.140    2023-12-28               polygon          primary
# 249  193.900    2023-12-29               polygon          primary
#
#     selected_source_vendor source_vendor symbol           timestamp  \
# 0                  polygon       polygon   AAPL 2023-01-03 05:00:00
# 1                  polygon       polygon   AAPL 2023-01-04 05:00:00
# 2                  polygon       polygon   AAPL 2023-01-05 05:00:00
# 3                  polygon       polygon   AAPL 2023-01-06 05:00:00
# 4                  polygon       polygon   AAPL 2023-01-09 05:00:00
# ..                     ...           ...    ...                 ...
# 245                polygon       polygon   AAPL 2023-12-22 05:00:00
# 246                polygon       polygon   AAPL 2023-12-26 05:00:00
# 247                polygon       polygon   AAPL 2023-12-27 05:00:00
# 248                polygon       polygon   AAPL 2023-12-28 05:00:00
# 249                polygon       polygon   AAPL 2023-12-29 05:00:00
#
#     validation_status       volume
# 0                None  112117471.0
# 1                None   89100633.0
# 2                None   80716808.0
# 3                None   87754715.0
# 4                None   70790813.0
# ..                ...          ...
# 245              None   37149570.0
# 246              None   28919310.0
# 247              None   48087681.0
# 248              None   34049898.0
# 249              None   42672148.0
#
# [250 rows x 16 columns]

# %%
import pyarrow.parquet as pq
pq.read_table(".quanto_data/canonical/equity_ohlcv/CSCO/daily/2023.parquet")
# Out:
# pyarrow.Table
# close: double
# creation_timestamp: string
# fallback_source_vendor: null
# high: double
# input_file_hashes: list<element: string>
#   child 0, element: string
# low: double
# open: double
# partition_day: string
# primary_source_vendor: string
# reconcile_method: string
# selected_source_vendor: string
# source_vendor: string
# symbol: string
# timestamp: timestamp[ns]
# validation_status: null
# volume: double
# ----
# close: [[47.94,47.55,46.88,48.32,48.58,...,50.09,50.28,50.44,50.48,50.52]]
# creation_timestamp: [["2026-01-09T21:09:36.572190+00:00","2026-01-09T21:09:36.572190+00:00","2026-01-09T21:09:36.572190+00:00","2026-01-09T21:09:36.572190+00:00","2026-01-09T21:09:36.572190+00:00",...,"2026-01-09T21:09:36.572190+00:00","2026-01-09T21:09:36.572190+00:00","2026-01-09T21:09:36.572190+00:00","2026-01-09T21:09:36.572190+00:00","2026-01-09T21:09:36.572190+00:00"]]
# fallback_source_vendor: [250 nulls]
# high: [[48.05,48.48,47.49,48.585,49.21,...,50.39,50.4,50.56,50.63,50.585]]
# input_file_hashes: [[["sha256:6bedbe64040cd0926c8a94b471272ab2767ac4f0029a4d30d99f392cdc92d1be"],["sha256:6bedbe64040cd0926c8a94b471272ab2767ac4f0029a4d30d99f392cdc92d1be"],...,["sha256:6bedbe64040cd0926c8a94b471272ab2767ac4f0029a4d30d99f392cdc92d1be"],["sha256:6bedbe64040cd0926c8a94b471272ab2767ac4f0029a4d30d99f392cdc92d1be"]]]
# low: [[47.31,47.17,46.76,47.275,48.22,...,49.84,50.05,50.28,50.42,50.22]]
# open: [[47.86,48.28,47.49,47.46,48.255,...,49.84,50.11,50.3,50.58,50.45]]
# partition_day: [["2023-01-03","2023-01-04","2023-01-05","2023-01-06","2023-01-09",...,"2023-12-22","2023-12-26","2023-12-27","2023-12-28","2023-12-29"]]
# primary_source_vendor: [["polygon","polygon","polygon","polygon","polygon",...,"polygon","polygon","polygon","polygon","polygon"]]
# reconcile_method: [["primary","primary","primary","primary","primary",...,"primary","primary","primary","primary","primary"]]
# ...

# %%
from pathlib import Path
print(Path(".quanto_data/canonical/equity_ohlcv/AAPL/daily/2023.parquet").resolve())
# Out:
# /Users/ahmed/PycharmProjects/Quanto/.quanto_data/canonical/equity_ohlcv/AAPL/daily/2023.parquet

# %%
from research.eval.regime_slicing import compute_regime_slices

# %%
compute_regime_slices()
